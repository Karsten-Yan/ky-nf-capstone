# %%
import pandas as pd

# %%
df_mod_1 = pd.read_table("data/modified_rep_1.tsv")

# %%
df_mod_1.iloc[197]
# Out:
# #0_0        NaN
# ref_0000    NaN
# Name: (#0_1, ref_0000), dtype: object

# %%
import csv
with open('data/modified_rep_1.tsv', 'r') as csvfile:
    data = csv.reader(csvfile, delimiter='\t', quotechar='|')
    for i in data:
        if len(i) == 2:
            print(i)
# Out:
# ['#0_0', 'ref_0000']
# ['#0_1', 'ref_0000']
# ['#0_2', 'ref_0000']
# ['#0_3', 'ref_0000']
# ['#0_4', 'ref_0000']
# ['#0_5', 'ref_0000']
# ['#0_6', 'ref_0000']
# ['#0_7', 'ref_0000']
# ['#0_8', 'ref_0000']
# ['#0_9', 'ref_0000']
# ['#0_10', 'ref_0000']
# ['#0_11', 'ref_0000']
# ['#0_12', 'ref_0000']
# ['#0_13', 'ref_0000']
# ['#0_14', 'ref_0000']
# ['#0_15', 'ref_0000']
# ['#0_16', 'ref_0000']
# ['#0_17', 'ref_0000']
# ['#0_18', 'ref_0000']
# ['#0_19', 'ref_0000']
# ['#0_20', 'ref_0000']
# ['#0_21', 'ref_0000']
# ['#0_22', 'ref_0000']
# ['#0_23', 'ref_0000']
# ['#0_24', 'ref_0000']
# ['#0_25', 'ref_0000']
# ['#0_26', 'ref_0000']
# ['#0_27', 'ref_0000']
# ['#0_28', 'ref_0000']
# ['#0_29', 'ref_0000']
# ['#0_30', 'ref_0000']
# ['#0_31', 'ref_0000']
# ['#0_32', 'ref_0000']
# ['#0_33', 'ref_0000']
# ['#0_34', 'ref_0000']
# ['#0_35', 'ref_0000']
# ['#0_36', 'ref_0000']
# ['#0_37', 'ref_0000']
# ['#0_38', 'ref_0000']
# ['#0_39', 'ref_0000']
# ['#0_40', 'ref_0000']
# ['#0_41', 'ref_0000']
# ...
